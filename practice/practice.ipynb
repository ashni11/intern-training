# %%
class Fan:
    def __init__(self,brand,speed):
        self.brand=brand
        self.speed=speed
    def turn_on(self):
        print(self.brand,"is running")
        print("at speed ",self.speed)
        
s1=Fan("usha fan","3")
s1.turn_on()
# Out:
# usha fan is running
# at speed  3

# %%
class bottle:
    def __init__(self,color,capacity):
        self.color=color
        self.capacity=capacity
    def display(self):
        print(self.color,"bottle")
        print(self.capacity)
        
s1=bottle("red","3litre")
s2=bottle("blue","2litre")
s1.display()
s2.display()
# Out:
# red bottle
# 3litre
# blue bottle
# 2litre

# %%
class Dog:
    def __init__(self,name,breed):
        self.name=name
        self.breed=breed
    def bark(self):
        print(self.name,"is")
        print(self.breed)
        
s1=Dog("tommy","barking")
s1.bark()
# Out:
# tommy is
# barking

# %%
class bankAccont:
    def __init__(self,balance):
        self.balance=balance
    def deposit(self,amount):
        self.balance=self.balance+ amount
        print("amount deposited:",self.balance)
    def withdraw(self,amount):
        if amount>self.balance:
            return "insufficient balance"
        self.balance=self.balance-amount
    def check_balance(self):
        print("current balance",self.balance)
    
a1=bankAccont(500)
a1.deposit(200)
b=a1.withdraw(1000)
print(b)
a1.check_balance()
# Out:
# amount deposited: 700
# insufficient balance
# current balance 700

# %%
class BankAccount:
    def __init__(self,balance):
        self.balance=balance
    def deposit(self,amount):
        self.balance=self.balance+ amount
        print("amount deposited:",self.balance)
    def withdraw(self,amount):
        if amount>self.balance:
            return "insufficient balance"
        self.balance=self.balance-amount
        return f"withdraw successful {amount}"
    def check_balance(self):
        print("current balance",self.balance)
        
balance = int(input("Enter starting balance: "))
account = BankAccount(balance)

        
        
while True:
    print("\n 1.Deposit")
    print("2.withdraw")
    print("3.check_balance")
    print("4.exit")
    
    choice = int(input("enter the choice:"))
    if choice ==1:
        amount= int(input("enter the amount to deposit:"))
        account.deposit(amount)
    
    elif choice ==2:
        amount= int(input("enter the amount to withdraw:"))
        U= account.withdraw(amount)
        print(U)
        
    elif choice ==3:
        account.check_balance()
        
    elif choice ==4:
        print("thank you")
        break 

    else:
        print("invalid choice")
# Out:
#  1.Deposit
# 2.withdraw
# 3.check_balance
# 4.exit
#
#  1.Deposit
# 2.withdraw
# 3.check_balance
# 4.exit
#
#  1.Deposit
# 2.withdraw
# 3.check_balance
# 4.exit

# %%
class Movieticket:
    def __init__(self,movie_name,seats_available):
        self.movie_name= movie_name
        self.seats_available=seats_available
        
    def book_tickets(self):
        if self.seats_available > 0:
            self.seats_available = self.seats_available-1
            print("ticket booked")
            print("seats available:",self.seats_available)
        else:
            print("house full")
            
m1=Movieticket ("leo",2)
m1.book_tickets()
m1.book_tickets()
m1.book_tickets()
# Out:
# ticket booked
# seats available: 1
# ticket booked
# seats available: 0
# house full

# %%
class cart:
    def __init__(self,total_amount):
        self.total_amount=total_amount
        
    def add_items(self,price):
        self.total_amount=self.total_amount+price
        print("added items",self.total_amount)
        
    def remove_items(self,price):
        self.total_amount=self.total_amount-price
        print("removed items",self.total_amount)
        
c1=cart(1000)
c1.add_items(200)
c1.remove_items(222)
# Out:
# added items 1200
# removed items 978

# %% [markdown]
# oops - part 2 [1. INheritance]

# %%
# single level inheritance

class A:
    def f1(self):
        print("f1 works")
    def f2(self):
        print("f2 works")
        
class B(A):
    def f3(self):
        print("f3 works")
    def f4(self):
        print("f4 works")
        
        
s =B()
s.f1()
# Out:
# f1 works

# %%
# Multi level inheritance

class A:
    def f1(self):
        print("f1 works")
    def f2(self):
        print("f2 works")
        
class B(A):
    def f3(self):
        print("f3 works")
    def f4(self):
        print("f4 works")
        
        
class C(B):
    def f5(self):
        print("f5 works")
    
        
        
s =C()
s.f1()
# Out:
# f1 works

# %%
#MRO 

class A:
    def f1(self):
        print("f1 works")
    def f2(self):
        print("f2 works")
    def show(self):
        print(" in A show")
        
class B:
    def f3(self):
        print("f3 works")
    def f4(self):
        print("f4 works")
    def show(self):
        print("in B show")        
        
class C(A,B):
    def f5(self):
        print("f5 works")
    
        
        
s =C()
s.show()
# Out:
#  in A show

# %%
class A:
    def __init__(self):
        print("A init")
    def f1(self):
        print("f1 works")

class B(A):
    def __init__(self):
        print("B init")
    def f4(self):
        print("f4 works")
            
        
s =B()
s.f1()
# Out:
# B init
# f1 works

# %%
class A:
    def __init__(self):
        print("A init")
    def f1(self):
        print("f1 works")

class B(A):
    def __init__(self):
        super().__init__()
        print("B init")
    def f4(self):
        print("f4 works")
            
        
s =B()
s.f1()
# Out:
# A init
# B init
# f1 works

# %%
#A school has teachers and students
# Every person has:name,age.
# Students have:roll_number.
# Teachers have:subject


class person:
    def __init__(self,name,age):
        self.name= name
        self.age = age
        
class students(person):
    def __init__(self,name,age,roll_number):
        super().__init__(name,age)
        self.roll_number= roll_number
        
s =students("ashni",23,111)
print(s.name)
# Out:
# ashni

# %%
class vehicle:
    def start(self):
        print("vehicle started")
    def stop(self):
        print("vehicle stopped")
        
    
class car(vehicle):
    pass

class bike(vehicle):
    pass

s=car()
s.start()
# Out:
# vehicle started

# %% [markdown]
# POLYMORPHISM[DUCK TYPING]

# %%
class laptop:
    def build(self):
        print("laptop builds")
class person:
    def code(self,machine : laptop):
        print("person building")
        machine.build()
        
dell=laptop()
a =person()
a.code(dell)
# Out:
# person building
# laptop builds

# %%
class laptop:
    def build(self):
        print("laptop builds")
        
class desktop:
    def build(self):
        print("desktop builds")
class person:
    def code(self,machine : laptop):
        print("person building")
        machine.build()
        
dell=laptop()
beast=desktop()
a =person()
#a.code(dell)
a.code(beast)
# Out:
# person building
# desktop builds

# %% [markdown]
# operator overloading

# %%
class account:
    def __init__(self,name,balance):
        self.name=name
        self.balance=balance
        
    def __str__(self):
        return f'{self.name}:{self.balance}'
    
    def __add__(self,other):
        return account('comined',self.balance +other.balance)
    
    def __gt__(self,other):
        return self.balance > other.balance
        
u1=account("ashni",1000)
u2= account("kavya",2000)
combined = u1 + u2
print(u2)
print(combined)

if u1>u2:
    print("ashni pays the bill")
else :
    print("kavya pays the bill")
# Out:
# kavya:2000
# comined:3000
# kavya pays the bill

# %%
#method overiding :
class A:
    def show(self):
        print("in A show ")
        
class B(A):
    def show(self):
        print("in B show")
              
a=B()
a.show()
# Out:
# in B show

# %% [markdown]
# practices questions

# %%
class person:
    def __init__(self,name):
        self.name=name

class student(person):
    def __init__(self,name,roll_number):
        super().__init__(name)
        self.roll_number= roll_number
        
s1=student("ashni",123)
print(s1.name)
print(s1.roll_number)
# Out:
# ashni
# 123

# %%
class vehicle:
    def start(self):
        print("vehicles started")
        
class car(vehicle):
    pass

c1=car()
c1.start()
# Out:
# vehicles started

# %%
class animal():
    def __init__(self,name):
        self.name= name
        
class dog(animal):
    def __init__(self,name,breed):
        super().__init__(name)
        self.breed= breed

a1=dog("doggie","beagle") 
print(a1.name)
# Out:
# doggie

# %%
class Animal:
    def speak(self):
        print("animal speaking")

class dog(Animal):
    def speak(self):
        print("bark")

class cat(Animal):
    def speak(self):
        print("meow")
        
animal=[dog(), cat()]

for i in animal:
    i.speak()
# Out:
# bark
# meow

# %%
class shape :
    def __init__(self,name):
        self.name=name
    def area(self):
        pass
        
class rectangle(shape):
    def __init__(self,l,b):
         super().__init__("rectangle")
         self.l=l
         self.b=b
         
    def area(self):
        return self.l * self.b
    
class circle(shape):
    def __init__(self,r):
         super().__init__("cicle")
         self.r=r
         
    def area(self):
        return 3.14 *self.r * self.r
    

r1 = rectangle(10, 5)
c1 = circle(7)

print(f"{r1.name} Area =", r1.area())
print(f"{c1.name} Area =", c1.area())
# Out:
# rectangle Area = 50
# cicle Area = 153.86

# %% [markdown]
# day 8 [modules,libr,package,VE]

# %%
import module
# Out:
# have fun

# %%
import module

module.fun()
# Out:
# have fun

# %%
import module
print (module)
# Out:
# <module 'module' from 'c:\\genworx\\intern-training\\practice\\module.py'>

# %%
import random

print(random.randint(1,10))
# Out:
# 1

# %%
from datetime import datetime
now = datetime.now()
print(now)
# Out:
# 2026-06-17 11:25:46.603437

# %%
from datetime import date

today =date.today()
print(today)
# Out:
# 2026-06-17

# %%
from datetime import datetime
now=datetime.now()
print(now.strftime("%d-%m-%y"))
# Out:
# 17-06-26

# %%
import json

# some JSON:
x =  '{ "name":"John", "age":30, "city":"New York"}'

# parse x:
y = json.loads(x)

# the result is a Python dictionary:
print(y["age"])
# Out:
# 30

# %%
import json

# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
import json

# a Python object (dict):
x = {
  "name": "John",
  "age": 30,
  "city": "New York"
}

# convert into JSON:
y = json.dumps(x)

# the result is a JSON string:
print(y)
# Out:
# {"name": "John", "age": 30, "city": "New York"}

# %%
try:
    num = int(input("Enter a number: "))
    print(num)

except ValueError:
    print("Please enter a valid number")
# Out:
# Please enter a valid number

# %%
num = int(input("Enter a number: "))
print(num)
# Out:
# 2

# %%
try:
    num = int(input("Enter number: "))
except ValueError:
    print("Invalid input")
else:
    print("You entered:", num)
# Out:
# You entered: 11

# %%
try:
    num = int(input("Enter number: "))
except ValueError:
    print("Invalid input")
finally:
    print("Program ended")
# Out:
# Program ended

# %%
age = int(input("Enter age: "))

if age < 18:
    raise ValueError("Age must be 18 or above")
